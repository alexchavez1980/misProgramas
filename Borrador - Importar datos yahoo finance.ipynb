# %% [markdown]
# # **Hola.**
# ### Este es un programa de prueba para la lectura de un archivo .csv

# %%
pip install yfinance
# Out:
# ERROR: Operation cancelled by user
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/cli/base_command.py", line 180, in _main
#     status = self.run(options, args)
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/cli/req_command.py", line 199, in wrapper
#     return func(self, options, args)
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/commands/install.py", line 319, in run
#     reqs, check_supported_wheels=not options.target_dir
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/resolution/resolvelib/resolver.py", line 128, in resolve
#     requirements, max_rounds=try_to_avoid_resolution_too_deep
#   File "/usr/local/lib/python3.7/dist-packages/pip/_vendor/resolvelib/resolvers.py", line 473, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "/usr/local/lib/python3.7/dist-packages/pip/_vendor/resolvelib/resolvers.py", line 341, in resolve
# ...

# %%
import pandas as pnd
import yfinance as yf
from pandas_datareader import data as pdr

# %%
#df = yf.download('BTC-USD', period = '6mo')
#df = yf.download('BTC-USD', start = '2017-08-01', end = '2021-12-27')
df = yf.download('BTC-USD', period = '1mo', interval = '5m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.head() # Muestra las primeras filas.
# Out:
#                                    Open          High  ...     Adj Close    Volume
# Datetime                                               ...
# 2021-11-29 22:30:00+00:00  58259.851562  58259.851562  ...  58238.257812         0
# 2021-11-29 22:35:00+00:00  58209.996094  58217.433594  ...  58185.707031         0
# 2021-11-29 22:40:00+00:00  58185.191406  58206.976562  ...  58195.238281  12677120
# 2021-11-29 22:45:00+00:00  58181.332031  58225.335938  ...  58157.613281  13096960
# 2021-11-29 22:50:00+00:00  58225.562500  58225.562500  ...  58084.644531  27017216
#
# [5 rows x 6 columns]

# %%
df.tail() # Muestra las últimas filas.
# Out:
#                                    Open          High  ...     Adj Close    Volume
# Datetime                                               ...
# 2021-12-29 22:10:00+00:00  47179.710938  47220.695312  ...  47125.007812  24602624
# 2021-12-29 22:15:00+00:00  47156.199219  47212.386719  ...  47179.105469  25171968
# 2021-12-29 22:20:00+00:00  47197.312500  47247.234375  ...  47247.234375  25982976
# 2021-12-29 22:25:00+00:00  47327.515625  47333.074219  ...  47333.074219  54345728
# 2021-12-29 22:29:02+00:00  47363.902344  47363.902344  ...  47363.902344         0
#
# [5 rows x 6 columns]

# %%
df.shape()  #Forma de los datos
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-0e566b70f572> in <module>()
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.index()  # ERROR
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-79c83efb9910> in <module>()
# ----> 1 df.index()
#
# TypeError: 'DatetimeIndex' object is not callable

# %%
df.describe() # Estadística
# Out:
#                Open          High  ...     Adj Close        Volume
# count   8586.000000   8586.000000  ...   8586.000000  8.586000e+03
# mean   49895.280008  49936.616844  ...  49895.021629  3.283132e+07
# std     3074.174906   3074.756264  ...   3074.112683  1.488148e+08
# min    45584.648438  45662.890625  ...  45032.945312  0.000000e+00
# 25%    47875.659180  47916.786133  ...  47869.487305  0.000000e+00
# 50%    49013.880859  49056.367188  ...  49013.085938  0.000000e+00
# 75%    50814.112305  50845.625977  ...  50813.051758  3.398554e+07
# max    59048.136719  59113.402344  ...  59041.683594  9.063979e+09
#
# [8 rows x 6 columns]

# %%
df.mean() # Media. df.median() para la mediana. df.std() para la desviación estándar.
# Out:
# Open         4.989528e+04
# High         4.993662e+04
# Low          4.985311e+04
# Close        4.989502e+04
# Adj Close    4.989502e+04
# Volume       3.283132e+07
# dtype: float64

# %%
df.count()  # Cantidad de valores no nulos
# Out:
# Open         8586
# High         8586
# Low          8586
# Close        8586
# Adj Close    8586
# Volume       8586
# dtype: int64

# %%
df.max()  # Valor mas alto. df.min() para el mínimo
# Out:
# Open         5.904814e+04
# High         5.911340e+04
# Low          5.900683e+04
# Close        5.904168e+04
# Adj Close    5.904168e+04
# Volume       9.063979e+09
# dtype: float64

# %%
df[2] # ERROR

# %%
df.isnull() # Chequear si hay nulos.
# Out:
#                             Open   High    Low  Close  Adj Close  Volume
# Datetime
# 2021-11-29 22:30:00+00:00  False  False  False  False      False   False
# 2021-11-29 22:35:00+00:00  False  False  False  False      False   False
# 2021-11-29 22:40:00+00:00  False  False  False  False      False   False
# 2021-11-29 22:45:00+00:00  False  False  False  False      False   False
# 2021-11-29 22:50:00+00:00  False  False  False  False      False   False
# ...                          ...    ...    ...    ...        ...     ...
# 2021-12-29 22:10:00+00:00  False  False  False  False      False   False
# 2021-12-29 22:15:00+00:00  False  False  False  False      False   False
# 2021-12-29 22:20:00+00:00  False  False  False  False      False   False
# 2021-12-29 22:25:00+00:00  False  False  False  False      False   False
# 2021-12-29 22:29:02+00:00  False  False  False  False      False   False
#
# [8586 rows x 6 columns]

# %%
df.isnull().sum() # Chequear si hay nulos. Y los suma.
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df['Open']
# Out:
# Datetime
# 2021-11-29 22:30:00+00:00    58259.851562
# 2021-11-29 22:35:00+00:00    58209.996094
# 2021-11-29 22:40:00+00:00    58185.191406
# 2021-11-29 22:45:00+00:00    58181.332031
# 2021-11-29 22:50:00+00:00    58225.562500
#                                  ...
# 2021-12-29 22:10:00+00:00    47179.710938
# 2021-12-29 22:15:00+00:00    47156.199219
# 2021-12-29 22:20:00+00:00    47197.312500
# 2021-12-29 22:25:00+00:00    47327.515625
# 2021-12-29 22:29:02+00:00    47363.902344
# Name: Open, Length: 8586, dtype: float64

# %%
df_depurado = df.drop(columns=['Open','High','Low','Adj Close','Volume']) # Me quedó pendiente revisar el inplace=True
df_depurado.plot()

# %%
df.iloc[0]  # Chequeo de filas por indexado.
# Out:
# Open         58259.851562
# High         58259.851562
# Low          58229.578125
# Close        58238.257812
# Adj Close    58238.257812
# Volume           0.000000
# Name: 2021-11-29 22:30:00+00:00, dtype: float64

# %%
df.iloc[0:20] # Chequeo de varias filas por indexado.
# Out:
#                                    Open          High  ...     Adj Close    Volume
# Datetime                                               ...
# 2021-11-29 22:30:00+00:00  58259.851562  58259.851562  ...  58238.257812         0
# 2021-11-29 22:35:00+00:00  58209.996094  58217.433594  ...  58185.707031         0
# 2021-11-29 22:40:00+00:00  58185.191406  58206.976562  ...  58195.238281  12677120
# 2021-11-29 22:45:00+00:00  58181.332031  58225.335938  ...  58157.613281  13096960
# 2021-11-29 22:50:00+00:00  58225.562500  58225.562500  ...  58084.644531  27017216
# 2021-11-29 22:55:00+00:00  58168.230469  58168.230469  ...  58081.941406  52475904
# 2021-11-29 23:00:00+00:00  58094.812500  58094.812500  ...  57915.777344         0
# 2021-11-29 23:05:00+00:00  57888.277344  57965.195312  ...  57964.441406         0
# 2021-11-29 23:10:00+00:00  57971.136719  58021.175781  ...  57964.484375         0
# 2021-11-29 23:15:00+00:00  57962.871094  58005.207031  ...  57943.585938         0
# ...

# %%
df.loc[2021-11-29]  # Chequeo de filas por el "Datetime" de ése data set. HAY QUE CHEQUEARLO
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-dfb6005aa45c> in <module>()
# ----> 1 df.loc[2021-11-29]  # Chequeo de filas por el "Datetime" de ése data set.
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ...

# %%
df.iloc[[1,2],[1,2]] # Chequeo de varias filas Y columnas por indexado.
# Out:
#                                    High           Low
# Datetime
# 2021-11-29 22:35:00+00:00  58217.433594  58185.707031
# 2021-11-29 22:40:00+00:00  58206.976562  58179.941406

# %%
df[df["Close"] < 50000] # Filtrado por condición.
# Out:
#                                    Open          High  ...     Adj Close      Volume
# Datetime                                               ...
# 2021-12-04 05:00:00+00:00  50330.277344  50576.933594  ...  48946.269531   481030144
# 2021-12-04 05:05:00+00:00  48624.570312  48978.843750  ...  48946.707031   822382592
# 2021-12-04 05:10:00+00:00  49474.578125  49474.578125  ...  49078.449219  1078214656
# 2021-12-04 05:15:00+00:00  49047.910156  49168.312500  ...  48906.984375   612618240
# 2021-12-04 05:20:00+00:00  48756.148438  48756.148438  ...  47652.585938           0
# ...                                 ...           ...  ...           ...         ...
# 2021-12-29 22:10:00+00:00  47179.710938  47220.695312  ...  47125.007812    24602624
# 2021-12-29 22:15:00+00:00  47156.199219  47212.386719  ...  47179.105469    25171968
# 2021-12-29 22:20:00+00:00  47197.312500  47247.234375  ...  47247.234375    25982976
# ...

# %%
df[(df["Close"] > 50000) & (df["Close"] < 55000)] # Filtrado por varias condiciones.
# Out:
#                                    Open          High  ...     Adj Close     Volume
# Datetime                                               ...
# 2021-12-03 17:00:00+00:00  55049.656250  55049.656250  ...  54857.683594          0
# 2021-12-03 17:05:00+00:00  54948.941406  55019.570312  ...  54899.863281  149757952
# 2021-12-03 17:30:00+00:00  54956.750000  54956.750000  ...  54856.355469          0
# 2021-12-03 17:35:00+00:00  54824.972656  54969.824219  ...  54969.824219   43630592
# 2021-12-03 18:35:00+00:00  55000.300781  55000.300781  ...  54959.375000          0
# ...                                 ...           ...  ...           ...        ...
# 2021-12-28 01:10:00+00:00  50329.464844  50329.464844  ...  50195.667969          0
# 2021-12-28 01:15:00+00:00  50201.097656  50237.605469  ...  50237.605469   80037888
# 2021-12-28 01:20:00+00:00  50204.304688  50204.304688  ...  50133.644531   40423424
# ...

# %%
#@title Gráfica de torta
datos["Total fruits"]= datos["Apples"] + datos["Pears"]
datos.plot.pie( y="Total fruits", autopct='%1.1f%%')

# %%
ds_iris = pnd.read_csv('iris.csv',header=0)
print(ds_iris.head())
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# # Nueva sección

# %%
import matplotlib.pyplot as plt

x=ds_iris['sepal.length']
y=ds_iris['sepal.width']
plt.scatter(x,y)
plt.show()
