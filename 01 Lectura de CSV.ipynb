# %% [markdown]
# # **Lectura de archivos**

# %%
# FALTA VINCULAR CON GITHUB

# %% [markdown]
# ## Método 1: Desde mi google drive

# %%
#@title Conectar con el drive
from google.colab import drive 
drive.mount('/content/drive')

# %%
#@title Librería y lectura de archivo
import pandas as pd # Importo la librería
path = "/content/drive/MyDrive/csv/iris.csv"  # Defino la ruta
ds_iris_del_drive = pd.read_csv(path) # Leo el archivo
ds_iris_del_drive.describe

# %% [markdown]
# ## Método 2: Desde mi PC

# %%
#@title Conectar con la PC y cargar el archivo en Colab
from google.colab import files 
files.upload()

# %%
#@title Lectura de archivo
ds_iris_del_pc = pd.read_csv('iris.csv') # Leo el archivo
ds_iris_del_pc.head()

# %% [markdown]
# ## Método 3: Desde interné. Usé de ejemplo un instrumento finaciero

# %%
#@title Instalar librería Yahoo finance
pip install yfinance  # OJO. Si sale error, instalarlo en la primera línea

# %%
#@title Importo las dos librerías que necesito.
import pandas as pd
import yfinance as yf
from pandas_datareader import data as pdr

# %%
#df = yf.download('BTC-USD', period = '6mo')
#df = yf.download('BTC-USD', start = '2017-08-01', end = '2021-12-27')
ds_BTC = yf.download('BTC-USD', period = '1mo', interval = '5m')
ds_BTC.describe
